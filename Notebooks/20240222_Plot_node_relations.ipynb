# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
markers = ['b.CATENIN',
       'cleavedCas', 'CyclinB', 'GAPDH', 'IdU', 'Ki.67', 'p.4EBP1',
       'p.Akt.Ser473.', 'p.AKT.Thr308.', 'p.AMPK', 'p.BTK', 'p.CREB', 'p.ERK',
       'p.FAK', 'p.GSK3b', 'p.H3', 'p.HER2', 'p.JNK', 'p.MAP2K3', 'p.MAPKAPK2',
       'p.MEK', 'p.MKK3.MKK6', 'p.MKK4', 'p.NFkB', 'p.p38', 'p.p53',
       'p.p90RSK', 'p.PDPK1', 'p.PLCg2', 'p.RB', 'p.S6', 'p.S6K', 'p.SMAD23',
       'p.SRC', 'p.STAT1', 'p.STAT3', 'p.STAT5']

# %%
cell_line = "BT20"
time = 7
data_path = "/dccstor/ipc1/CAR/DREAM/DREAMdata/Time_aligned_per_cell_line/CL_incl_test/tenth_perctile/"
data = pd.read_csv(f"{data_path}{cell_line}.csv")
data = data[data["time"]==time]

# %%
imek = data[data["treatment"]=="iMEK"]
egf = data[data["treatment"]=="EGF"]

# %%
sns.scatterplot(data=egf, x="p.MEK", y="p.FAK", hue="p.ERK", s=10)
# Out:
# <AxesSubplot:xlabel='p.MEK', ylabel='p.FAK'>

# %%
temp = egf.sample(n=100)

# %%
# %matplotlib notebook

# %%
plot_axes = plt.axes(projection = '3d')
plot_axes.scatter3D(temp['p.MEK'], temp["p.FAK"], temp["p.ERK"], s=1)
plot_axes.set_xlabel('MEK')
plot_axes.set_ylabel('FAK')
plot_axes.set_zlabel('ERK')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
